# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Extraindo os dados

# %%
#Criando um dicionário com todos os caminhos dos arquivos. Isso vai ser bom porque utilizarei as chaves para criar uma coluna de "Ano"
arquivos = {
    '2022': 'data/dados_vacinados_2022.csv',
    '2023': 'data/dados_vacinados_2023.csv',
    '2024': 'data/dados_vacinados_2024.csv'
}

lista_dataframes = [] #Para armazenar todos os dataframes

for ano, arquivo in arquivos.items():
    try:
        df = pd.read_csv(arquivo, encoding='utf-8') #No meu caso, eu não utilizei "sep=';'" porque esse dataset é separado por vígula mesmo, que é o padrão da função

        df['ano_origem'] = ano #Utilizando o a chave "ano" para criar uma coluna nova em cada dataframe com o ano correspondente

        lista_dataframes.append(df)
    except Exception as e:
        print(f"Erro ao ler os dados do ano {ano}: {e}")


df = pd.concat(lista_dataframes, ignore_index=True) #Concatenando todos os DFs
print(f"Total de linhas no df unificado: {len(df)}")
# Out:
# Total de linhas no df unificado: 406500

# %% [markdown]
# <h2> Transformação </h2>

# %%
#Verificando o resultado final e as informações sobre os tipos de dados e 
display(df.head(5))
display(df.info())
# Out:
#    _id  faixa_etaria  idade       sexo raca_cor municipio  \
# 0    1  35 a 39 anos   37.0  MASCULINO    PARDA    RECIFE
# 1    2  50 a 54 anos   52.0  MASCULINO   BRANCA    RECIFE
# 2    3  55 a 59 anos   58.0   FEMININO   BRANCA    OLINDA
# 3    4  35 a 39 anos   35.0  MASCULINO    PARDA    RECIFE
# 4    5  40 a 44 anos   40.0  MASCULINO    PRETA    RECIFE
#
#                              grupo                          categoria  \
# 0  PÚBLICO EM GERAL (18 a 59 anos)                             OUTRAS
# 1  PÚBLICO EM GERAL (18 a 59 anos)                             OUTROS
# 2  PÚBLICO EM GERAL (18 a 59 anos)                             OUTROS
# 3        TRABALHADORES DA EDUCAÇÃO  REDE PRIVADA - ENSINO FUNDAMENTAL
# 4           TRABALHADORES DA SAÚDE                                NaN
#
#          lote                                  vacina_fabricante  \
# 0      FM2948                             3 - COMIRNATY (PFIZER)
# 1      FT5177                             3 - COMIRNATY (PFIZER)
# 2      FP7082                             3 - COMIRNATY (PFIZER)
# 3     205H21A   4 - JANSSEN COVID-19 VACCINE (JOHNSON & JOHNSON)
# 4  219VCD273Z  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)
#
#    descricao_dose                                               cnes  \
# 0               2  DS 2: CNES: 6897029 - POLICLÍNICA SALOMÃO KELNER
# 1               4   DS 2: CNES: 6897029 - POLICLÍNICA SALOMÃO KELNER
# 2               1  DS 1: CNES: 000507 - POLICLÍNICA GOUVEIA DE BA...
# 3               3    DS 8: CNES: 0001198 - UBT ARISTARCHO DE AZEVEDO
# 4               2     DS 6: CNES: 0001392 - MIGUEL DE LIMA VALVERDE.
#
#    sistema_origem       data_vacinacao ano_origem
# 0  Conecta Recife  2022-03-25T00:00:00       2022
# 1  Conecta Recife  2022-12-06T00:00:00       2022
# 2  Conecta Recife  2022-06-04T00:00:00       2022
# 3  Conecta Recife  2022-03-03T00:00:00       2022
# 4  Conecta Recife  2022-02-08T00:00:00       2022
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406500 entries, 0 to 406499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   _id                406500 non-null  int64
#  1   faixa_etaria       406498 non-null  object
#  2   idade              406499 non-null  float64
#  3   sexo               406493 non-null  object
#  4   raca_cor           406426 non-null  object
#  5   municipio          406498 non-null  object
#  6   grupo              406500 non-null  object
#  7   categoria          50010 non-null   object
#  8   lote               406413 non-null  object
#  9   vacina_fabricante  406500 non-null  object
#  10  descricao_dose     406500 non-null  int64
#  11  cnes               406500 non-null  object
#  12  sistema_origem     406500 non-null  object
#  13  data_vacinacao     406500 non-null  object
#  14  ano_origem         406500 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 46.5+ MB
# None

# %% [markdown]
# <h3> Verificando valores únicos em cada uma das minhas colunas. </h3>

# %%
df.nunique(dropna=False) #Usar o "dropna=False" faz com que ele leve em consideração valores nunlos
# Out:
# _id                  379750
# faixa_etaria             22
# idade                   114
# sexo                      4
# raca_cor                  8
# municipio               312
# grupo                    27
# categoria               156
# lote                    315
# vacina_fabricante         6
# descricao_dose            5
# cnes                      9
# sistema_origem            2
# data_vacinacao          361
# ano_origem                3
# dtype: int64

# %% [markdown]
# <h3>Verificando os valores nulos por coluna</h3>

# %%
print("Valores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# Valores ausentes por coluna:
# _id                       0
# faixa_etaria              2
# idade                     1
# sexo                      7
# raca_cor                 74
# municipio                 2
# grupo                     0
# categoria            356490
# lote                     87
# vacina_fabricante         0
# descricao_dose            0
# cnes                      0
# sistema_origem            0
# data_vacinacao            0
# ano_origem                0
# dtype: int64

# %% [markdown]
# <p>Verificando a quantidade de valores nulos, iremos começar a tratar alguns deles.</p>
# <ul>
#     <li>sexo: Apenas 7 linhas vazias. Nessa coluna, temos os valores "MACULINO", "FEMININO" e "OUTROs". Podemos passar todas as linhas nulas para "OUTROS"</li>
#     <li>raca_cor: Temos 74 linhas com valores nulos. Nessa coluna, temos os valores 'PARDA', 'BRANCA', 'PRETA', 'AMARELA', 'INDÍGENA', 'ÍNDIGENA' e
#        'NÃO INFORMADO'. Para todos os nulos, podemos apenas colocar "NÃO INFORMADO".</li>
#     <li>categoria: Temos 155 valores diferentes (156 se contamor os nulos). Entre esses valores, temos "OUTROS" e "OUTRAS". Primeiro, podemos padronizar e tornar todos como apenas "OUTROS", e, posteriormente, classifica-los todos os nulos como "OUTROS". </li>
#     <li>lote: Temos 87 linhas com valores nulos. Poderíamos criar uma nova categoria de "Não informado" e popular essas linhas com essa nova categoria. Entretanto, particularmente, eu acho que essa coluna não agrega muito para o dataset, então, iremos excluí-la posteriormente.</li>
# </ul>
# <p></p>

# %%
#Vamos printar os valores únicos de algumas colunas
print("Valores únicos da coluna 'sexo': \n", df['sexo'].unique())
print("Valores únicos da coluna 'raca_cor': \n", df['raca_cor'].unique())
print("Valores unicos da coluna 'categoria' (Top 10): \n", df['categoria'].value_counts().head(10))
print("Valores unicos da coluna 'lote' (Top 10): \n", df['lote'].value_counts().head(10))
# Out:
# Valores únicos da coluna 'sexo':
#  ['MASCULINO' 'FEMININO' 'OUTROS' nan]
# Valores únicos da coluna 'raca_cor':
#  ['PARDA' 'BRANCA' 'PRETA' 'AMARELA' 'INDÍGENA' 'ÍNDIGENA' nan
#  'NÃO INFORMADO']
# Valores unicos da coluna 'categoria' (Top 10):
#  categoria
# OUTRAS                                                                                            10654
# DIABETES MELLITUS                                                                                  4932
# OUTROS                                                                                             3997
# GRÁVIDAS                                                                                           2646
# HIPERTENSÃO ARTERIAL RESISTENTE NOS ESTÁGIOS 1,2 E 3 COM LESÃO EM ÓRGÃO-ALVO E/OU COMORBIDADE.     2172
# PESSOAS COM OBESIDADE MÓRBIDA                                                                      1614
# CARDIOPATIA HIPERTENSIVA                                                                           1348
# IMUNOSSUPRIMIDOS                                                                                   1289
# REDE PÚBLICA - ENSINO SUPERIOR                                                                     1238
# REDE PRIVADA - ENSINO SUPERIOR                                                                     1233
# Name: count, dtype: int64
# Valores unicos da coluna 'lote' (Top 10):
#  lote
# FL4222        35867
# FM2951        34076
# FM2967        33948
# 205F21A       29145
# FP8290        20305
# 210527        18810
# FJ8766        15871
# 201H21A       15214
# 219VCD273Z    14313
# 21PVCD362W    11809
# Name: count, dtype: int64

# %% [markdown]
# <p>Agora, vamos tratar preencher os valores nulos com os valores que definimos.</p>

# %%
#Aplicando as transformações:

df['sexo'] =  df['sexo'].fillna('OUTROS') #Preenchendo os valores nulos da coluna 'sexo' por "OUTROS"
df['raca_cor'] = df['raca_cor'].fillna('NÃO INFORMADO') #Preenchendo os valores nulos da coluna 'raca_cor' para "NÃO INFORMADO"
df.loc[df['categoria'] == "OUTRAS", "categoria"] = "OUTROS" #Primeiro, substituindo os valores "OUTRAS" para "OUTROS", para padronizar
df['categoria'] = df['categoria'].fillna('OUTROS') #Agora, preenchendo os valores nulos com "OUTROS"

# %% [markdown]
# <h3>Padronizando colunas</h3>

# %% [markdown]
# <p>Agora, iremos padronizar algumas colunas.</p>
# <p>A primeira coluna será a de "grupos". Essa coluna possui diversos valores que podem ser simplificados. Por exemplo, eixstem vários valores diferentes para crianças, como "CRIANÇAS DE 03 E 04 ANOS" e "CRIANÇAS DE 05 A 11 ANOS - Prioritárias", que no fim, podem ser simplificadas para apenas "Crianças". Isso facilitará caso a gente queira realizar alguma análise nesses grupos posteriormente.</p>>

# %%
print("\nValores únicos na coluna 'grupos':\n", df['grupo'].unique())
# Out:
# Valores únicos na coluna 'grupos':
#  ['PÚBLICO EM GERAL (18 a 59 anos)' 'TRABALHADORES DA EDUCAÇÃO'
#  'TRABALHADORES DA SAÚDE' 'IDOSOS' 'TRABALHADORES PORTUÁRIOS'
#  'OUTRAS PRIORIDADES' 'PESSOAS COM COMORBIDADES' 'GESTANTES E PUÉRPERAS'
#  'TRABALHADORES DE TRANSPORTE METROVIÁRIO E FERROVIÁRIO'
#  'CRIANÇAS DE 05 A 11 ANOS' 'TRABALHADORES INDUSTRIAIS E BANCÁRIOS'
#  'TRABALHADORES DA LIMPEZA URBANA'
#  'PESSOAS COM VIAGEM PARA EXTERIOR (ESTUDO/PESQUISA/TRABALHO/TRATAMENTO DE SAÚDE)'
#  'TRABALHADORES DE TRANSPORTE AÉREO' 'CAMINHONEIROS'
#  'PESSOAS EM SITUAÇÃO DE RUA' 'PÚBLICO EM GERAL - MENOR DE 18 ANOS'
#  'TRABALHADORES DE TRANSPORTE COLETIVO RODOVIÁRIO'
#  'TRABALHADORES DA ASSISTÊNCIA SOCIAL'
#  'TRABALHADORES DE TRANSPORTE AQUAVIÁRIO'
#  'CRIANÇAS DE 05 A 11 ANOS - Prioritárias'
#  'GESTANTES E PUÉRPERAS - 12 A 17 ANOS'
#  'GESTANTES E PUÉRPERAS NÃO RESIDENTES EM RECIFE'
#  'PESSOAS COM COMORBIDADES - 12 A 17 ANOS'
#  'PESSOAS COM DEFICIÊNCIA - 12 A 17 ANOS'
#  'CRIANÇAS DE 05 A 11 ANOS - Síndrome de Down' 'CRIANÇAS DE 03 E 04 ANOS']

# %% [markdown]
# <p>Padronizando os valores:</P>

# %%
def simplificar_grupos(grupo_original):

    grupo = str(grupo_original)

    if 'CRIANÇAS' in grupo:
        return 'CRIANÇAS'
    
    elif'GESTANTES' in grupo or "PUÉRPERAS" in grupo:
        return "GESTANTES E PUÉRPERAS"
    
    elif "TRABALHADORES" in grupo or "CAMINHONEIROS" in grupo:
        return "TRABALHADORES (DIVERSOS)"
    
    elif "DEFICIÊNCIA" in grupo:
        return "PESSOAS COM DEFICIÊNCIA"
    
    elif "COMORBIDADES" in grupo:
        return "PESSOAS COM COMORBIDADES"
    
    elif "PÚBLICO" in grupo:
        return "PÚBLICO EM GERAL"
    
    elif "IDOSOS" in grupo:
        return "IDOSOS"
    
    elif "RUA" in grupo:
        return "PESSOAS EM SITUAÇÃO DE RUA"
    
    elif "VIAGEM" in grupo:
        return "PESSOAS COM VIAGEM PARA EXTERIOR"
    
    else:
        return "OUTRAS PRIORIDADES"
    
df['grupo'] = df['grupo'].apply(simplificar_grupos)

# %% [markdown]
# <p>Agora, vamos tratar a coluna "cnes"</p>

# %%
print("\nValores únicos na coluna 'cnes':\n", df['cnes'].unique())
# Out:
# Valores únicos na coluna 'cnes':
#  ['DS 2: CNES: 6897029 - POLICLÍNICA SALOMÃO KELNER '
#  'DS 2: CNES: 6897029 - POLICLÍNICA SALOMÃO KELNER'
#  'DS 1: CNES: 000507 - POLICLÍNICA GOUVEIA DE BARROS'
#  'DS 8: CNES: 0001198 - UBT ARISTARCHO DE AZEVEDO'
#  'DS 6: CNES: 0001392 - MIGUEL DE LIMA VALVERDE.'
#  'DS 3: CNES: 000612 - POLICLÍNICA ALBERT SABIN'
#  'DS 5: CNES: 000701 - MATERNIDADE BANDEIRA FILHO'
#  'DS 7: CNES: 0000647 - POLICLINICA CLEMENTINO FRAGA'
#  'DS 4: CNES: 0000639 - UBS JOAQUIM CAVALCANTE']

# %% [markdown]
# <p>Nessa coluna, temos alguns problemas:</p>
# <ul>
#     <li>Existem dois valores que são o mesmo, mudando apenas que um deles, possuii um espaço no final</li>
#     <li>Há valor com ponto final, mas a maioria, não está</li>
#     <li>Cada valor é uma mistura de três valores: Distrito, Código e Nome da unidade. Podemos destrinchar e colocar cada um em colunas separadas, sendo elas: distrito_sanitario, codigo_cnes e nome_unidade</li>
# </ul>
#
# <p>Primeiro, vamos remover os espaços em branco e o ponto final:</p>

# %%
df['cnes'] = df['cnes'].astype(str).str.strip() #Removendo o espaço final em branco
df['cnes'] = df['cnes'].astype(str).str.rstrip('.') #Removendo o ponto final do final
print("\nValores únicos na coluna 'cnes':\n", df['cnes'].unique()) #Printando para confirmar
# Out:
# Valores únicos na coluna 'cnes':
#  ['DS 2: CNES: 6897029 - POLICLÍNICA SALOMÃO KELNER'
#  'DS 1: CNES: 000507 - POLICLÍNICA GOUVEIA DE BARROS'
#  'DS 8: CNES: 0001198 - UBT ARISTARCHO DE AZEVEDO'
#  'DS 6: CNES: 0001392 - MIGUEL DE LIMA VALVERDE'
#  'DS 3: CNES: 000612 - POLICLÍNICA ALBERT SABIN'
#  'DS 5: CNES: 000701 - MATERNIDADE BANDEIRA FILHO'
#  'DS 7: CNES: 0000647 - POLICLINICA CLEMENTINO FRAGA'
#  'DS 4: CNES: 0000639 - UBS JOAQUIM CAVALCANTE']

# %% [markdown]
# <p>Agora, vamos separar os dados para inserir nas colunas "distrito_sanitario", "codigo_cnes" e "nome_unidade"</p>

# %%
df_temp = df['cnes'].str.split(' - ', n=1, expand=True) #Separando a string e criando um dataframe temporário

df['codigo_cnes'] = df_temp[0] #Atribuindo a coluna 'codigo_cnes' a coluna 0 do df_temp
df['nome_unidade'] = df_temp[1].str.strip() #Atribuindo a coluna 'nome_unidade' a coluna 1 do df_temp

df['distrito_sanitario'] = df['codigo_cnes'].str.split(':', n=1).str[0].str.strip()
df['codigo_cnes'] = df['codigo_cnes'].str.split(':').str[2].str.strip()

df = df.drop('cnes', axis=1)

# %%
print(df.columns.tolist()) #Printando as colunas atuais só para confirmar
print("\nValores únicos na coluna 'cnes':\n", df['codigo_cnes'].unique()) #Printando para confirmar
print("\nValores únicos na coluna 'cnes':\n", df['nome_unidade'].unique()) #Printando para confirmar
print("\nValores únicos na coluna 'cnes':\n", df['distrito_sanitario'].unique()) #Printando para confirmar
# Out:
# ['_id', 'faixa_etaria', 'idade', 'sexo', 'raca_cor', 'municipio', 'grupo', 'categoria', 'lote', 'vacina_fabricante', 'descricao_dose', 'sistema_origem', 'data_vacinacao', 'ano_origem', 'codigo_cnes', 'nome_unidade', 'distrito_sanitario']
#
# Valores únicos na coluna 'cnes':
#  ['6897029' '000507' '0001198' '0001392' '000612' '000701' '0000647'
#  '0000639']
#
# Valores únicos na coluna 'cnes':
#  ['POLICLÍNICA SALOMÃO KELNER' 'POLICLÍNICA GOUVEIA DE BARROS'
#  'UBT ARISTARCHO DE AZEVEDO' 'MIGUEL DE LIMA VALVERDE'
#  'POLICLÍNICA ALBERT SABIN' 'MATERNIDADE BANDEIRA FILHO'
#  'POLICLINICA CLEMENTINO FRAGA' 'UBS JOAQUIM CAVALCANTE']
#
# Valores únicos na coluna 'cnes':
#  ['DS 2' 'DS 1' 'DS 8' 'DS 6' 'DS 3' 'DS 5' 'DS 7' 'DS 4']

# %% [markdown]
# <p>Agora, vamos tratar a coluna "vacina_fabricante"</p>

# %%
print("\nValores únicos na coluna 'vacina_fabricante':\n", df['vacina_fabricante'].unique()) #Printando para confirmar
# Out:
# Valores únicos na coluna 'vacina_fabricante':
#  ['3 - COMIRNATY (PFIZER)'
#  '4 - JANSSEN COVID-19 VACCINE (JOHNSON & JOHNSON)'
#  '2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)'
#  '1 - CORONAVAC - SINOVAC (BUTANTAN)'
#  '6 - CORONAVAC - SINOVAC (BUTANTAN) PEDIÁTRICA'
#  '5 - COMIRNATY (PFIZER) - PEDIÁTRICA']

# %% [markdown]
# <p>Assim como na coluna de "grupo", nessa também temos várias informações em uma string só, sendo elas:</p>
# <ul>
#     <li>1. ID da vacina</li>
#     <li>2. Nome da vacina</li>
#     <li>3. Fabricante/Laboratório</li>
#     <li>4. Público </li>
# </ul>
#
# <p>Aplicaremos o mesmo tratamento que foi feito na coluna anterior. Iremos separar toda a string em 4 colunas, de acordo com a informação que representam.</p>

# %%
df['id_vacina'] = df['vacina_fabricante'].str.split('-').str[0].str.strip() #Primeiro, criando a coluna 'id_vacina" para amrzenar os IDs

df['fabricante_laboratorio'] = df['vacina_fabricante'].str.extract(r'\((.*?)\)') #Pegando o nome do laboratório que está entre parenteses

df['publico_alvo'] = df['vacina_fabricante'].str.split(') - ', n=1, regex=False).str[1] #Pegando o público alvo "PEDIATRA"
df['publico_alvo'] = df['publico_alvo'].fillna('GERAL') #Aplicando o fillna para que os valores nulos sejam preenchidos com "GERAL"

temp_nome = df['vacina_fabricante'].str.split(' - ', n=1).str[1] #Salvando uma parte temporaria da string
df['nome_vacina'] = temp_nome.str.split(' (', n=1, regex=False).str[0] #Aplicando split novamente para pegar o nome de fato

colunas_para_ver = ['id_vacina', 'fabricante_laboratorio', 'publico_alvo', 'nome_vacina']
print(display(df[colunas_para_ver].head()))
# Out:
#   id_vacina fabricante_laboratorio publico_alvo  \
# 0         3                 PFIZER        GERAL
# 1         3                 PFIZER        GERAL
# 2         3                 PFIZER        GERAL
# 3         4      JOHNSON & JOHNSON        GERAL
# 4         2                FIOCRUZ        GERAL
#
#                            nome_vacina
# 0                            COMIRNATY
# 1                            COMIRNATY
# 2                            COMIRNATY
# 3             JANSSEN COVID-19 VACCINE
# 4  CHADOX1NCOV-19 - OXFORD/ASTRAZENECA
# None

# %% [markdown]
# <h3>Removendo colunas</h3>

# %% [markdown]
# <p>Agora, vamos remover as seguintes colunas:</p>
# <ul>
#     <li>lote: A coluna 'lote' possui algunas valores nulos a serem tratados. Entretanto, acredito que ela em si não agregue muito para o dataset, então, iremos remove-la</li>
#     <li>faixa_etaria: Apesar de estar bem padronizada, por já termos a idade, acredito que não precisamos dessa coluna.</li>
#     <li>_id: A coluna "id" possui menos valores únicos do que a quantidade total de linhas, o que é um problema. Iremos remvoer a coluna e criar um novo id.</li>
# </ul>

# %%
df = df.drop(columns=['_id', 'lote', 'faixa_etaria'], axis=1) #Removendo as colunas

df = df.reset_index(drop=True) #Removendo od indices antigos
df = df.reset_index() #Criando uma nova coluna "index" com novos indices
df = df.rename(columns={'index': 'id'}) #Renomeando o nome que foi criado pelo pandas para colocar "id"

display(df.head())
# Out:
#    id  idade       sexo raca_cor municipio                     grupo  \
# 0   0   37.0  MASCULINO    PARDA    RECIFE          PÚBLICO EM GERAL
# 1   1   52.0  MASCULINO   BRANCA    RECIFE          PÚBLICO EM GERAL
# 2   2   58.0   FEMININO   BRANCA    OLINDA          PÚBLICO EM GERAL
# 3   3   35.0  MASCULINO    PARDA    RECIFE  TRABALHADORES (DIVERSOS)
# 4   4   40.0  MASCULINO    PRETA    RECIFE  TRABALHADORES (DIVERSOS)
#
#                            categoria  \
# 0                             OUTROS
# 1                             OUTROS
# 2                             OUTROS
# 3  REDE PRIVADA - ENSINO FUNDAMENTAL
# 4                             OUTROS
#
#                                    vacina_fabricante  descricao_dose  \
# 0                             3 - COMIRNATY (PFIZER)               2
# 1                             3 - COMIRNATY (PFIZER)               4
# 2                             3 - COMIRNATY (PFIZER)               1
# 3   4 - JANSSEN COVID-19 VACCINE (JOHNSON & JOHNSON)               3
# 4  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)               2
#
#    sistema_origem       data_vacinacao ano_origem codigo_cnes  \
# 0  Conecta Recife  2022-03-25T00:00:00       2022     6897029
# 1  Conecta Recife  2022-12-06T00:00:00       2022     6897029
# 2  Conecta Recife  2022-06-04T00:00:00       2022      000507
# 3  Conecta Recife  2022-03-03T00:00:00       2022     0001198
# 4  Conecta Recife  2022-02-08T00:00:00       2022     0001392
#
#                     nome_unidade distrito_sanitario id_vacina  \
# 0     POLICLÍNICA SALOMÃO KELNER               DS 2         3
# 1     POLICLÍNICA SALOMÃO KELNER               DS 2         3
# 2  POLICLÍNICA GOUVEIA DE BARROS               DS 1         3
# 3      UBT ARISTARCHO DE AZEVEDO               DS 8         4
# 4        MIGUEL DE LIMA VALVERDE               DS 6         2
#
#   fabricante_laboratorio publico_alvo                          nome_vacina
# 0                 PFIZER        GERAL                            COMIRNATY
# 1                 PFIZER        GERAL                            COMIRNATY
# 2                 PFIZER        GERAL                            COMIRNATY
# 3      JOHNSON & JOHNSON        GERAL             JANSSEN COVID-19 VACCINE
# 4                FIOCRUZ        GERAL  CHADOX1NCOV-19 - OXFORD/ASTRAZENECA

# %% [markdown]
# <h3>Removendo valores nulos</h3>

# %% [markdown]
# <p>Após o tratamento dos valores nulos, ainda assim, sobraram duas colunas com valores nulos:</p>

# %%
print("Valores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# Valores ausentes por coluna:
# id                        0
# idade                     1
# sexo                      0
# raca_cor                  0
# municipio                 2
# grupo                     0
# categoria                 0
# vacina_fabricante         0
# descricao_dose            0
# sistema_origem            0
# data_vacinacao            0
# ano_origem                0
# codigo_cnes               0
# nome_unidade              0
# distrito_sanitario        0
# id_vacina                 0
# fabricante_laboratorio    0
# publico_alvo              0
# nome_vacina               0
# dtype: int64

# %% [markdown]
# <p>Como são poucas linhas, irei remover as linhas com valores nulos.</p>

# %%
df = df.dropna()
print("Valores ausentes por coluna:")
print(df.isnull().sum())
# Out:
# Valores ausentes por coluna:
# id                        0
# idade                     0
# sexo                      0
# raca_cor                  0
# municipio                 0
# grupo                     0
# categoria                 0
# vacina_fabricante         0
# descricao_dose            0
# sistema_origem            0
# data_vacinacao            0
# ano_origem                0
# codigo_cnes               0
# nome_unidade              0
# distrito_sanitario        0
# id_vacina                 0
# fabricante_laboratorio    0
# publico_alvo              0
# nome_vacina               0
# dtype: int64

# %% [markdown]
# <h3>Alterando os tipos de algumas colunas</h3>

# %% [markdown]
# <p>Agora, iremos mudar o tipo das colunas 'idade' e 'ano_origem', que atualmente, estão como 'object'. Iremos alterar o tipo de ambas para inteiro.</p>

# %%
df['idade'] = df['idade'].astype(int)
df['ano_origem'] = df['ano_origem'].astype(int)

# %% [markdown]
# <p>Além disso, iremos transformar o tipo da coluna de data.</p>

# %%
df['data_vacinacao'] =  pd.to_datetime(df['data_vacinacao'])

# %% [markdown]
# <h3>Resultado final</h3>

# %% [markdown]
# <p>Terminamos a etapa de transformação. Vamos verificar como o nosso dataset ficou no final.</p>

# %%
display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406497 entries, 0 to 406499
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      406497 non-null  int64
#  1   idade                   406497 non-null  int64
#  2   sexo                    406497 non-null  object
#  3   raca_cor                406497 non-null  object
#  4   municipio               406497 non-null  object
#  5   grupo                   406497 non-null  object
#  6   categoria               406497 non-null  object
#  7   vacina_fabricante       406497 non-null  object
#  8   descricao_dose          406497 non-null  int64
#  9   sistema_origem          406497 non-null  object
#  10  data_vacinacao          406497 non-null  datetime64[ns]
#  11  ano_origem              406497 non-null  int64
#  12  codigo_cnes             406497 non-null  object
#  13  nome_unidade            406497 non-null  object
#  14  distrito_sanitario      406497 non-null  object
#  15  id_vacina               406497 non-null  object
#  16  fabricante_laboratorio  406497 non-null  object
#  17  publico_alvo            406497 non-null  object
#  18  nome_vacina             406497 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(14)
# memory usage: 62.0+ MB
# None
#    id  idade       sexo raca_cor municipio                     grupo  \
# 0   0     37  MASCULINO    PARDA    RECIFE          PÚBLICO EM GERAL
# 1   1     52  MASCULINO   BRANCA    RECIFE          PÚBLICO EM GERAL
# 2   2     58   FEMININO   BRANCA    OLINDA          PÚBLICO EM GERAL
# 3   3     35  MASCULINO    PARDA    RECIFE  TRABALHADORES (DIVERSOS)
# 4   4     40  MASCULINO    PRETA    RECIFE  TRABALHADORES (DIVERSOS)
#
#                            categoria  \
# 0                             OUTROS
# 1                             OUTROS
# 2                             OUTROS
# 3  REDE PRIVADA - ENSINO FUNDAMENTAL
# 4                             OUTROS
#
#                                    vacina_fabricante  descricao_dose  \
# 0                             3 - COMIRNATY (PFIZER)               2
# 1                             3 - COMIRNATY (PFIZER)               4
# 2                             3 - COMIRNATY (PFIZER)               1
# 3   4 - JANSSEN COVID-19 VACCINE (JOHNSON & JOHNSON)               3
# 4  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)               2
#
#    sistema_origem data_vacinacao  ano_origem codigo_cnes  \
# 0  Conecta Recife     2022-03-25        2022     6897029
# 1  Conecta Recife     2022-12-06        2022     6897029
# 2  Conecta Recife     2022-06-04        2022      000507
# 3  Conecta Recife     2022-03-03        2022     0001198
# 4  Conecta Recife     2022-02-08        2022     0001392
#
#                     nome_unidade distrito_sanitario id_vacina  \
# 0     POLICLÍNICA SALOMÃO KELNER               DS 2         3
# 1     POLICLÍNICA SALOMÃO KELNER               DS 2         3
# 2  POLICLÍNICA GOUVEIA DE BARROS               DS 1         3
# 3      UBT ARISTARCHO DE AZEVEDO               DS 8         4
# 4        MIGUEL DE LIMA VALVERDE               DS 6         2
#
#   fabricante_laboratorio publico_alvo                          nome_vacina
# 0                 PFIZER        GERAL                            COMIRNATY
# 1                 PFIZER        GERAL                            COMIRNATY
# 2                 PFIZER        GERAL                            COMIRNATY
# 3      JOHNSON & JOHNSON        GERAL             JANSSEN COVID-19 VACCINE
# 4                FIOCRUZ        GERAL  CHADOX1NCOV-19 - OXFORD/ASTRAZENECA

# %% [markdown]
# <h2>Carregamento: Transformando em um esquema estrela e injetando o dataset no Banco de Dados PostgreSQL</h2>

# %%
#Instalando as dependências necessárias
# !pip install sqlalchemy
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (2.0.44)
# Requirement already satisfied: greenlet>=1 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.13.0)
# Requirement already satisfied: psycopg2-binary in c:\users\victo\appdata\local\programs\python\python313\lib\site-packages (2.9.10)

# %% [markdown]
# <h3>Iniciando a transformação para um esquema estrela</h3>

# %% [markdown]
# <p>Para transformar em um esquema estrela, eu vou precisar criar as dimensões e a tabela de fato</p>
# <p>Podemos ter cinco dimensões, sendo elas:</p>
# <ul>
#     <li>Dimensão paciente (sexo, raca_cor, grupo e categoria)</li>
#     <li>Dimensão localidade (municipio)</li>
#     <li>Dimensão vacina (nome_vacina, fabricante_laboratorio, id_vacina e publico_alvo)</li>
#     <li>Dimensão unidade (nome_unidade, distrito_sanitario, codigo_cnes e sistema_origem)</li>
#     <li>Dimensão tempo (dia, mes, ano, trimestre e dia_semana)</li>
# <ul>

# %%
#1. Criando a Dimensão Paciente (Quem foi vacinadow)
colunas_paciente = ['sexo', 'raca_cor', 'grupo', 'categoria'] #Separando quais colunas irão formar a dimensão do paciente

dim_paciente = df[colunas_paciente].drop_duplicates().reset_index(drop=True)
dim_paciente = dim_paciente.reset_index().rename(columns={'index': 'id_paciente_sk'})

print(f"Dimensão Paciente: {len(dim_paciente)} perfis")

#2. Criando a Dimensão Localidade (Onde o paciente mora?)
colunas_localidade = ['municipio'] #Separando a única coluna que vai formar a dimensão localidade

dim_localidade = df[colunas_localidade].drop_duplicates().reset_index(drop=True) 

#Criando mais níveis para a dimensão, já que ela tem apenas um nível
dim_localidade['estado'] = 'Pernambuco' 
dim_localidade['uf'] = 'PE'
dim_localidade['regiao'] = 'Nordeste'
dim_localidade['pais'] = 'Brasil'
dim_localidade = dim_localidade.reset_index().rename(columns={'index': 'id_localidade_sk'})

print(f"Dimensão Localidade: {len(dim_localidade)} municípios")

#3. Dimensão da vacina (O que foi aplicado?)

colunas_vacina = ['nome_vacina', 'fabricante_laboratorio', 'id_vacina', 'publico_alvo'] #Separando quais colunas irão formar a dimensão da vacina

dim_vacina = df[colunas_vacina].drop_duplicates().reset_index(drop=True) 
dim_vacina = dim_vacina.reset_index().rename(columns={'index': 'id_vacina_sk'})

print(f"Dimensão Vacina: {len(dim_vacina)} tipos")

#4. Criando a Dimensão Unidade (Onde foi a aplicação?)
colunas_unidade = ['nome_unidade', 'distrito_sanitario', 'codigo_cnes', 'sistema_origem'] #Separando quais colunas irão formar a dimensão da unidade

dim_unidade = df[colunas_unidade].drop_duplicates().reset_index(drop=True) 
dim_unidade = dim_unidade.reset_index().rename(columns={'index': 'id_unidade_sk'})

print(f"Dimensão Vacina: {len(dim_unidade)} unidades")

#5. Criando a Dimensão Tempo (Quando ocorreu?)

datas_unicas = df[['data_vacinacao']].drop_duplicates().sort_values('data_vacinacao').reset_index(drop=True)
datas_unicas['dia'] = datas_unicas['data_vacinacao'].dt.day
datas_unicas['mes'] = datas_unicas['data_vacinacao'].dt.month
datas_unicas['ano'] = datas_unicas['data_vacinacao'].dt.year
datas_unicas['trimestre'] = datas_unicas['data_vacinacao'].dt.quarter
datas_unicas['dia_semana'] = datas_unicas['data_vacinacao'].dt.day_name(locale='pt_BR.utf8') 

dim_tempo = datas_unicas.reset_index().rename(columns={'index': 'id_tempo_sk'})
print(f"Dimensão Tempo criada: {len(dim_tempo)} dias registrados.")
# Out:
# Dimensão Paciente: 1137 perfis
# Dimensão Localidade: 311 municípios
# Dimensão Vacina: 6 tipos
# Dimensão Vacina: 16 unidades
# Dimensão Tempo criada: 361 dias registrados.

# %% [markdown]
# <p>Agora, vamos montar a nossa tabela fato</p>

# %%
#'Mergeando' todas as 5 dimensões para pegar os IDs, ou seja, as Surrogate Keys
fato = df.merge(dim_paciente, on=colunas_paciente, how='left')
fato = fato.merge(dim_localidade, on=colunas_localidade, how='left')
fato = fato.merge(dim_vacina, on=colunas_vacina, how='left')
fato = fato.merge(dim_unidade, on=colunas_unidade, how='left')
fato = fato.merge(dim_tempo[['data_vacinacao', 'id_tempo_sk']], on='data_vacinacao', how='left')

#Pegando apenas os IDs e a dose
colunas_fato = [
    'id_paciente_sk', 
    'id_localidade_sk',
    'id_vacina_sk', 
    'id_unidade_sk', 
    'id_tempo_sk',
    'ano_origem',
    'descricao_dose'
]

fato_vacinacao = fato[colunas_fato]
print(f"Fato pronta: {len(fato_vacinacao)} registros.")
# Out:
# Fato pronta: 406497 registros.

# %%
from sqlalchemy import create_engine

# Configurando a conexão
usuario_db = 'user'               
senha_db = 'password'                
host_db = 'host'                    
porta_db = 'port'                    
nome_banco_db = 'database'          

# Criando a "connection string"
DATABASE_URL = f'postgresql://{usuario_db}:{senha_db}@{host_db}:{porta_db}/{nome_banco_db}?client_encoding=utf8'
print("Tentando criar conexão com o banco...")

try:
    engine = create_engine(DATABASE_URL)
    print("Conexão bem-sucedida! Iniciando a carga do Esquema Estrela...")
    
    print("Carregando Dimensão Paciente...")
    dim_paciente.to_sql('dim_paciente', con=engine, if_exists='replace', index=False)
    
    print("Carregando Dimensão Localidade...")
    dim_localidade.to_sql('dim_localidade', con=engine, if_exists='replace', index=False)
    
    print("Carregando Dimensão Vacina...")
    dim_vacina.to_sql('dim_vacina', con=engine, if_exists='replace', index=False)
    
    print("Carregando Dimensão Unidade...")
    dim_unidade.to_sql('dim_unidade', con=engine, if_exists='replace', index=False)
    
    print("Carregando Dimensão Tempo...")
    dim_tempo.to_sql('dim_tempo', con=engine, if_exists='replace', index=False)

    
    print("Carregando Tabela Fato...")
    fato_vacinacao.to_sql('fato_vacinacao', con=engine, if_exists='replace', index=False)

    print("\nCARGA CONCLUÍDA! Todas as 6 tabelas do Esquema Estrela foram criadas.")

except Exception as e:
    print(f"\n--- ERRO! ---")
    print(f"Erro ao carregar os dados: {e}")
# Out:
# Tentando criar conexão com o banco...
# Conexão bem-sucedida! Iniciando a carga do Esquema Estrela...
# Carregando Dimensão Paciente...
# Carregando Dimensão Localidade...
# Carregando Dimensão Vacina...
# Carregando Dimensão Unidade...
# Carregando Dimensão Tempo...
# Carregando Tabela Fato...
#
# CARGA CONCLUÍDA! Todas as 6 tabelas do Esquema Estrela foram criadas.
